# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("Who is PM of India?")
response.content
# Out:
# 'The current Prime Minister of India is **Narendra Modi**.'

# %%
prompts = [
    ("system", "You are a java developer."),    ### "system", "ai", , 'user'
    ("user", "How to sort the array.")
]

res = model.invoke(prompts)
print(res.content)
# Out:
# In Java, there are several ways to sort an array, depending on the type of array and your specific needs. Here are the most common and recommended methods:
#
# **1. Using `Arrays.sort()` (The Most Common and Recommended Way)**
#
# The `java.util.Arrays` class provides a highly optimized and convenient `sort()` method for primitive arrays and object arrays.
#
# *   **For Primitive Arrays (e.g., `int[]`, `double[]`, `char[]`):**
#     The `Arrays.sort()` method uses a highly efficient algorithm (dual-pivot quicksort for primitives) that sorts the array in **ascending order** in place.
#
#     ```java
#     import java.util.Arrays;
#
#     public class SortPrimitiveArray {
#         public static void main(String[] args) {
#             int[] numbers = {5, 2, 8, 1, 9, 4};
#             System.out.println("Original array: " + Arrays.toString(numbers));
#
#             Arrays.sort(numbers); // Sorts the array in ascending order
#
# ...
