# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
response = model.stream("Explain the internal flow of running springboot application")
for chunk in response:
    print(chunk.content, end="")
# Out:
# When you run a Spring Boot application, a complex but well-orchestrated process unfolds to bring your application to life. Here's a breakdown of the internal flow, focusing on the key stages and components:
#
# **1. The `main` Method and `SpringApplication`:**
#
# *   **Entry Point:** Every Spring Boot application starts with a `main` method. This is the standard Java entry point.
# *   **`SpringApplication.run(YourApplication.class, args)`:** The crucial line in the `main` method is `SpringApplication.run()`. This static method from the `SpringApplication` class is the heart of the Spring Boot startup process.
# *   **`SpringApplication`'s Role:** `SpringApplication` is responsible for bootstrapping and launching your Spring Boot application. It handles:
#     *   **Creating a `SpringApplication` instance:** It determines whether to create a web application context (if dependencies like `spring-boot-starter-web` are present) or a non-web application context.
#     *   **Loading the `ApplicationContext`:** This is the central container for your Spring beans.
#     *   **Running the application:** It orchestrates the startup sequence.
#
# **2. Bootstrapping the `ApplicationContext`:**
#
# *   **`ApplicationContext`:** This is the core of the Spring framework. It's where all your beans (objects managed by Spring) are created, configured, and managed.
# *   **`SpringBootApplication` Annotation:** The `@SpringBootApplication` annotation on your main class is a convenience annotation that combines three other important annotations:
#     *   `@Configuration`: Marks the class as a source of bean definitions.
#     *   `@EnableAutoConfiguration`: Tells Spring Boot to automatically configure your application based on the dependencies it finds on the classpath. This is where the magic of "convention over configuration" happens.
#     *   `@ComponentScan`: Tells Spring to scan the current package and its sub-packages for components (e.g., `@Component`, `@Service`, `@Repository`, `@Controller`) and register them as beans in the `ApplicationContext`.
#
# *   **`Auto-configuration`:** This is a cornerstone of Spring Boot. Based on the presence of specific dependencies (like a web server like Tomcat or Netty, a database driver, etc.), Spring Boot automatically configures various beans. For example, if `spring-boot-starter-web` is present, it will automatically configure:
#     *   An embedded web server (Tomcat by default).
#     *   `DispatcherServlet` for handling web requests.
#     *   `HttpMessageConverters` for converting request/response bodies.
#     *   And many more.
#
# *   **`BeanDefinitionRegistry` and `BeanFactory`:** Internally, Spring uses these to manage the lifecycle of beans.
#     *   `BeanDefinitionRegistry`: Stores the metadata (definitions) of all beans.
#     *   `BeanFactory`: The actual factory responsible for creating and managing bean instances.
#
# **3. Web Server Initialization (for web applications):**
#
# *   **Embedded Server:** Spring Boot typically embeds a web server (Tomcat, Jetty, or Undertow) directly within your application JAR. This eliminates the need for external web server configuration.
# *   **`WebServer` Interface:** Spring Boot abstracts the server implementation through the `WebServer` interface.
# *   **Server Startup:** When the `ApplicationContext` is initialized, Spring Boot starts the embedded web server. This involves:
#     *   **Port Binding:** The server listens on a configured port (default is 8080).
#     *   **Servlet Container Setup:** The server sets up its internal servlet container.
#     *   **`DispatcherServlet` Registration:** Spring Boot registers the `DispatcherServlet` with the embedded server. The `DispatcherServlet` is the front controller responsible for routing incoming web requests to the appropriate controllers.
#
# **4. `DispatcherServlet` and Request Handling:**
#
# *   **Front Controller:** The `DispatcherServlet` acts as the central hub for all incoming web requests.
# *   **Request Mapping:** When a request arrives, the `DispatcherServlet` consults the `@RequestMapping` (or its more specific variants like `@GetMapping`, `@PostMapping`) annotations on your controller classes.
# *   **Handler Execution:** It identifies the appropriate controller method to handle the request based on the URL, HTTP method, and other criteria.
# *   **`HandlerAdapter`:** The `DispatcherServlet` uses `HandlerAdapter`s to invoke the matched controller method.
# *   **View Resolution (for traditional MVC):** If your application uses a view technology (like Thymeleaf, JSP), the `DispatcherServlet` will resolve the appropriate view and render it with the model data.
# *   **JSON/XML Serialization (for REST APIs):** For RESTful APIs, the controller method typically returns data structures that are then serialized into JSON or XML by `HttpMessageConverters` and sent back as the response.
#
# **5. Bean Lifecycle and Dependency Injection:**
#
# *   **Bean Creation:** Spring creates bean instances as needed, often during the application startup or when they are first requested.
# *   **Dependency Injection (DI):** Spring's core strength is DI. When a bean needs another bean, Spring injects it automatically, rather than the bean having to create it itself. This promotes loose coupling and testability.
# *   **Aware Interfaces:** Beans can implement "aware" interfaces (e.g., `ApplicationContextAware`, `BeanFactoryAware`) to get access to the Spring container.
# *   **Bean Post-Processors:** These are powerful extension points that can intercept bean creation and modification. They are used for tasks like applying AOP (Aspect-Oriented Programming) proxies.
#
# **6. Spring Boot Starters:**
#
# *   **Simplified Dependency Management:** Spring Boot Starters are pre-packaged sets of dependencies that provide a smooth experience for specific functionalities. For example, `spring-boot-starter-web` includes everything you need for building web applications.
# *   **Auto-configuration Trigger:** The presence of these starter dependencies is a key trigger for Spring Boot's auto-configuration process.
#
# **7. Profiles:**
#
# *   **Environment-Specific Configuration:** You can use Spring Profiles to activate different sets of configurations based on the environment (e.g., development, testing, production). This allows you to have different database connections, logging levels, etc., for different environments.
#
# **8. Externalized Configuration:**
#
# *   **`application.properties` / `application.yml`:** Spring Boot encourages externalizing configuration from your code. You can define properties in `application.properties` or `application.yml` files, which are automatically loaded by Spring Boot.
# *   **Environment Variables and Command-Line Arguments:** Spring Boot also supports overriding properties with environment variables and command-line arguments, making it highly flexible for deployment.
#
# **Simplified Flow Diagram:**
#
# ```
# +-----------------+     +-----------------------+     +-----------------------+
# |  main() method  | --> |   SpringApplication   | --> |     ApplicationContext|
# +-----------------+     |        .run()         |     |                       |
#                          +-----------------------+     |  - Auto-configuration |
#                                                        |  - Component Scanning |
#                                                        |  - Bean Definitions   |
#                                                        +-----------+-----------+
#                                                                    |
#                                                                    v
#                                                        +-----------+-----------+
#                                                        |   Embedded Web Server   |
#                                                        |      (e.g., Tomcat)   |
#                                                        |                       |
#                                                        |  - Listens on port    |
#                                                        |  - Registers DispatcherServlet |
#                                                        +-----------+-----------+
#                                                                    |
#                                                                    v
#                                                        +-----------+-----------+
#                                                        |     DispatcherServlet |
#                                                        |                       |
#                                                        |  - Receives requests  |
#                                                        |  - Maps to controllers|
#                                                        |  - Invokes handlers   |
#                                                        +-----------------------+
#                                                                    |
#                                                                    v
#                                                        +-----------------------+
#                                                        |     Controller Beans  |
#                                                        |                       |
#                                                        |  - Business Logic     |
#                                                        |  - Data Access        |
#                                                        +-----------------------+
# ```
#
# **In Summary:**
#
# Running a Spring Boot application is a journey from a simple `main` method to a fully functional, self-contained application. `SpringApplication` orchestrates the creation of the `ApplicationContext`, which then leverages auto-configuration to set up your application based on its dependencies. For web applications, an embedded server starts and the `DispatcherServlet` takes over, routing requests to your controllers. Throughout this process, Spring's powerful dependency injection and bean management mechanisms ensure that your application is well-structured, testable, and maintainable.
