# %%
from langchain_ollama import ChatOllama

# %%
model = ChatOllama(model="gemma3:1b")

# %%
response = model.invoke("What is the capital of India?")
print(response.content)
# Out:
# The capital of India is **New Delhi**.
#
# It’s located in the north-central part of the country. 😊

# %%
response
# Out:
# AIMessage(content='The capital of India is **New Delhi**. \n\nIt’s located in the north-central part of the country. 😊', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2026-05-17T12:57:08.5180455Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1099415100, 'load_duration': 342623300, 'prompt_eval_count': 16, 'prompt_eval_duration': 118460100, 'eval_count': 27, 'eval_duration': 536659100, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019e3603-0256-7c51-8b94-1370e74a9aa5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 27, 'total_tokens': 43})
