# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
texts = (
    "Today, I want to speak from the heart about three pillars "
    "that define the future of our nation: our youth, our education system, and our farmers."
)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=20)
texts = text_splitter.split_text(texts)
print(texts, end="\n\n")
# Out:
# ['Today, I want to speak from the heart about three', 'heart about three pillars that define the future', 'define the future of our nation: our youth, our', 'our youth, our education system, and our farmers.']

# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_loader = TextLoader("../data/speech.txt", encoding="utf-8")
texts = text_loader.load()
texts
# Out:
# [Document(metadata={'source': '../data/speech.txt'}, page_content='“My dear friends, students, and respected farmers,\n\nToday, I want to speak from the heart about three pillars that define the future of our nation:\nour youth, our education system, and our farmers.\n\n🎓 For the Youth\n\nYou are the energy that drives our state forward.\nOur commitment is to give you:\n\t•\tSkill-based education\n\t•\tDigital learning opportunities\n\t•\tBetter employment pathways\n\t•\tSupport for innovation, startups, and entrepreneurship\n\nYour dreams are not just your own—they are the dreams of our entire society.\n\n📚 For Education\n\nEducation must not be just a formality; it must be a force of transformation.\nWe aim to:\n\t•\tUpgrade government schools with smart classrooms\n\t•\tImprove teacher training\n\t•\tExpand scholarships for higher education\n\t•\tPromote technical and vocational courses\n\t•\tEnsure every child gets a fair opportunity to learn and grow\n\nEducation is the foundati
# ...

# %%
pdf_loader = PyPDFLoader("../data/data_science_syllabus.pdf")
pdfs = pdf_loader.load()
len(pdfs)
# Out:
# 10

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

# %%
text_chunks = splitter.split_text(texts[0].page_content)
text_chunks[0]
# Out:
# '“My dear friends, students, and respected farmers,\n\nToday, I want to speak from the heart about three pillars that define the future of our nation:\nour youth, our education system, and our farmers.\n\n🎓 For the Youth\n\nYou are the energy that drives our state forward.\nOur commitment is to give you:\n\t•\tSkill-based education\n\t•\tDigital learning opportunities\n\t•\tBetter employment pathways\n\t•\tSupport for innovation, startups, and entrepreneurship'

# %%
pdf_chunks = splitter.split_documents(pdfs)
pdf_chunks[0]
# Out:
# Document(metadata={'producer': 'Skia/PDF m137', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/137.0.0.0 Safari/537.36', 'creationdate': '2025-12-13T08:07:26+00:00', 'title': '📘 1-Year Roadmap: Data Analytics, Data Science & GenAI', 'moddate': '2025-12-13T08:07:26+00:00', 'source': '../data/data_science_syllabus.pdf', 'total_pages': 10, 'page': 0, 'page_label': '1'}, page_content='📘  1-Year Roadmap: Data \nAnalytics, Data Science & \nGenAI\n🎯  Goal: Placement-Ready for roles like Data Analyst, Data \nScientist, GenAI Engineer, LLM App Developer\n✅  Module 0: Orientation & Core Concepts\n🕒  Duration: 1\ue0892 Days\n🎯  Goal: Get students familiar with industry terms, career paths, tools, and how \neverything connects.\n🔹  Basic Industry Terms to Understand\nWhat is Data \ue081Structured, Semi-Structured, Unstructured)\nDifference between Data Analytics, Data Science, Machine Learning, and')
